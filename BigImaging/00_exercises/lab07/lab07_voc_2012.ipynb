# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os

import torchmetrics
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler
from numba import cuda
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

from PIL import Image

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
batch_size = 100
experiment_name = 'voc_01'
print('device:', device)
# Out:
# device: cuda

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision.io import read_image

class ImageDataset(Dataset):
    def __init__(self, root_dir, transform, split: list):
        images_root = root_dir + 'images/'
        targets_root = root_dir + 'targets/'
         # Get all image and target paths
        images_paths = [os.path.join(images_root, f) for f in os.listdir(images_root)]
        target_paths = [os.path.join(targets_root, f) for f in os.listdir(targets_root)]

        print(images_paths)      
        total_imgs_len = len(self.data)
        self.data = torch.tensor([])



        # Load images and targets into tensors
        images = [read_image(os.path.join) for f in os.]
        targets = [read_image(os.path.join(target_path, img)) for img in split]
        
        # Stack images and targets together along a new dimension
        self.data = torch.stack([torch.stack(images), torch.stack(targets)], dim=1)



    def __get_data__(self):
        print('TODO')
    
    def __len__(self):
        return len(self.data)
    
    def __get_item__(self, idx):
        image = read_image(self.data[idx, 0])
        target = read_image(self.data[idx, 1])
        return self.data[idx]

# %%
test = ImageDataset('data/', None, [0.5, 0.25, 0.25])
# Open the image file
image = Image.open("data/images/2007_000032.jpg")

# Display some information about the image
print("Image format:", image.format)
print("Image size:", image.size)
print("Image mode:", image.mode)

# Show the image
image.show()
# Out:
# ['2009_002320.jpg', '2008_003986.jpg', '2010_002382.jpg', '2008_000107.jpg', '2009_002984.jpg', '2010_004481.jpg', '2009_002897.jpg', '2010_001069.jpg', '2009_002346.jpg', '2009_000408.jpg', '2008_007998.jpg', '2009_000641.jpg', '2007_000783.jpg', '2010_005508.jpg', '2009_003172.jpg', '2011_001412.jpg', '2009_003975.jpg', '2007_000175.jpg', '2008_007433.jpg', '2010_002455.jpg', '2009_003703.jpg', '2007_009841.jpg', '2008_000105.jpg', '2011_000382.jpg', '2010_000503.jpg', '2011_000436.jpg', '2009_005056.jpg', '2008_008268.jpg', '2009_000409.jpg', '2007_004951.jpg', '2010_003651.jpg', '2010_000498.jpg', '2010_002150.jpg', '2008_003060.jpg', '2007_007447.jpg', '2011_002246.jpg', '2009_002390.jpg', '2009_004799.jpg', '2009_003857.jpg', '2007_002105.jpg', '2007_006490.jpg', '2008_007428.jpg', '2010_002422.jpg', '2010_000661.jpg', '2007_002227.jpg', '2008_002241.jpg', '2007_005951.jpg', '2009_002591.jpg', '2007_000039.jpg', '2009_000121.jpg', '2009_004091.jpg', '2008_002221.jpg', '2011_001
# ...

# %%
# create train dataloader
trainloader = torch.utils.data.DataLoader(
    train_ds,
    batch_size = batch_size,
    drop_last = True,
    shuffle = True,
    num_workers = 8
)
# create validation dataloader
valloader = torch.utils.data.DataLoader(
    val_ds,
    batch_size = batch_size,
    drop_last = False,
    shuffle = False,
    num_workers = 8
)
testloader = torch.utils.data.DataLoader(
    test_ds,
    batch_size = batch_size,
    drop_last = False,
    shuffle = False,
    num_workers = 8
)
