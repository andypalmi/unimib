# %%
import matplotlib.pyplot as plt
import numpy as np
from math import cos, sin

#              z   x   y      
output_shape = [8, 32, 32]
output_shape2 = [8, 28, 28]
output_shape3 = [20]

def map_layer(output_shape, angle: float = 3.14/6, offset: int = 0, offset_optional: int = 0):
    """
    Maps the shape of a layer in a neural network to a set of coordinates for visualization.

    Parameters:
    - output_shape (tuple): The shape of the layer's output tensor.
    - angle (float): The angle (in radians) at which the layer should be tilted.
    - offset (int): The offset value for the layer's coordinates.
    - offset_optional (int): An optional offset value to add to the maximum z-coordinate of the mapped layer.
   
    Returns:
    - mapped_layer (ndarray): An array of coordinates representing the mapped layer.
    - offset (int): The updated offset value.

    """
    mapped_layer = []
    vertices = []
    if len(output_shape) == 4:
        output_shape = output_shape[1:] # Drop batch size

    if len(output_shape) == 3: # 3D
        x_h = round(output_shape[1]*cos(angle))
        x_v = round(output_shape[1]*sin(angle))
        print(x_h, x_v)
        z = output_shape[0]
        y = output_shape[2]
    elif len(output_shape) == 1: # 1D -> Fully Connected
        print("1D")
        z = output_shape[0]
        y = 5
        x_h = round(y*cos(angle))
        x_v = round(y*sin(angle))
    
    vertices = [
            [offset - x_h/2, -y/2 - x_v/2], # Front bottom left
            [offset + z - x_h/2, -y/2 - x_v/2], # Front bottom right
            [offset + z - x_h/2, y/2 - x_v/2], # Front top right
            [offset - x_h/2, y/2 - x_v/2], # Front top left
            [offset + x_h/2, -y/2 + x_v/2], # Back bottom left
            [offset + z + x_h/2, -y/2 + x_v/2], # Back bottom right
            [offset + z + x_h/2, y/2 + x_v/2], # Back top right
            [offset + x_h/2, y/2 + x_v/2], # Back top left
        ]
    mapped_layer = [
        [vertices[0], vertices[1], vertices[2], vertices[3], vertices[0]], # Front face
        [vertices[4], vertices[5], vertices[6], vertices[7], vertices[4]], # Back face
        [vertices[0], vertices[4], vertices[7], vertices[3], vertices[0]], # Left face
        [vertices[1], vertices[5], vertices[6], vertices[2], vertices[1]], # Right face
        [vertices[3], vertices[7], vertices[6], vertices[2], vertices[3]], # Top face
        [vertices[0], vertices[4], vertices[5], vertices[1], vertices[0]], # Bottom face
    ]
    mapped_layer = np.array(mapped_layer).reshape(-1, 5, 2)
    offset += z + offset_optional
    print('Offset: ', offset, '. Vertices\n', vertices)
    return mapped_layer, offset


mapped_layer, offset = map_layer(output_shape)
mapped_layer2, offset2 = map_layer(output_shape2, offset=offset)
mapped_layer3, offset3 = map_layer(output_shape3, offset=offset2)

plt.gca().set_aspect('equal', adjustable='box')

for i, face in enumerate(mapped_layer):
    plt.fill(mapped_layer[i, :, 0], mapped_layer[i, :, 1], alpha=0.5, color='red', edgecolor='gray')

for i, face in enumerate(mapped_layer2):
    plt.fill(mapped_layer2[i, :, 0], mapped_layer2[i, :, 1], alpha=0.5, color='red', edgecolor='gray')
for i, face in enumerate(mapped_layer3):
    plt.fill(mapped_layer3[i, :, 0], mapped_layer3[i, :, 1], alpha=0.5, color='red', edgecolor='gray')

plt.title('Neural Network')
plt.show()
# Out:
# 28 16
# Offset:  8 . Vertices
#  [[-14.0, -24.0], [-6.0, -24.0], [-6.0, 8.0], [-14.0, 8.0], [14.0, -8.0], [22.0, -8.0], [22.0, 24.0], [14.0, 24.0]]
# 24 14
# Offset:  16 . Vertices
#  [[-4.0, -21.0], [4.0, -21.0], [4.0, 7.0], [-4.0, 7.0], [20.0, -7.0], [28.0, -7.0], [28.0, 21.0], [20.0, 21.0]]
# 1D
# Offset:  36 . Vertices
#  [[14.0, -3.5], [34.0, -3.5], [34.0, 1.5], [14.0, 1.5], [18.0, -1.5], [38.0, -1.5], [38.0, 3.5], [18.0, 3.5]]

# %%
import matplotlib.pyplot as plt
import numpy as np
from math import cos, sin
from mpl_toolkits.mplot3d import Axes3D  # Import for 3D plotting

#              z   x   y      
output_shape = [8, 32, 32]

def get_vertices(output_shape):
    x = output_shape[1]
    y = output_shape[2]
    z = output_shape[0]
    vertices = []
    vertices = [
        [0, 0, 0], # Front bottom left
        [x, 0, 0], # Front bottom right
        [x, y, 0], # Front top right
        [0, y, 0], # Front top left
        [0, 0, z], # Back bottom left
        [x, 0, z], # Back bottom right
        [x, y, z], # Back top right
        [0, y, z], # Back top left
    ]
    return vertices

ax.plot

# Function to create 3D cuboids representing layers
def plot_cube(ax, vertices, color='red', edgecolor='gray', alpha=0.5):
    x, y, z = zip(*vertices)
    
    ax.plot_surface(x*1, y*1, z*1, color=color, alpha=alpha, edgecolor=edgecolor)

# ... (rest of the code remains the same)

# Create a 3D figure and axes
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

vertices = get_vertices(output_shape)

ax.plot

plot_cube(ax, vertices)

# # Plot each layer as a 3D cuboid
# for vertices in mapped_layer:
#     plot_cube(ax, vertices)
# for vertices in mapped_layer2:
#     plot_cube(ax, vertices)
# for vertices in mapped_layer3:
#     plot_cube(ax, vertices)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Neural Network (3D)')

# Adjust viewing angle for better visualization
ax.view_init(30, 45)  # Adjust these values for different perspectives

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 43
#      39 vertices = get_vertices(output_shape)
#      41 ax.plot
# ---> 43 plot_cube(ax, vertices)
#      45 # # Plot each layer as a 3D cuboid
#      46 # for vertices in mapped_layer:
#      47 #     plot_cube(ax, vertices)
#    (...)
#      52
#      53 # Set labels and title
#      54 ax.set_xlabel('X')
#
# Cell In[16], line 31, in plot_cube(ax, vertices, color, edgecolor, alpha)
#      29 def plot_cube(ax, vertices, color='red', edgecolor='gray', alpha=0.5):
#      30     x, y, z = zip(*vertices)
# ---> 31     ax.plot_surface(x*1, y*1, z*1, color=color, alpha=alpha, edgecolor=edgecolor)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mpl_toolkits/mplot3d/axes3d.py:1699, in Axes3D.plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, **kwargs)
#    1629 """
#    1630 Create a surface plot.
#    1631
#    (...)
#    1694     Other keyword arguments are forwarded to `.Poly3DCollection`.
#    1695 """
#    1697 had_data = self.has_data()
# -> 1699 if Z.ndim != 2:
#    1700     raise ValueError("Argument Z must be 2-dimensional.")
#    1702 Z = cbook._to_unmasked_float_array(Z)
#
# AttributeError: 'tuple' object has no attribute 'ndim'
